# %% [markdown]
# <a href="https://colab.research.google.com/github/VinciGit00/Python/blob/main/Request/Daemon2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import os
from google.colab import drive

# %% [markdown]
# # Read the file

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
with open('out.json', 'r') as data:
    data = json.load(data)
print(data)
# Out:
# [['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['len
# ...

# %%
pretty = json.dumps(data, indent=4)

print(pretty)
# Out:
# [
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
# ...

# %% [markdown]
# # Modify the file

# %%
#data = list(data.items())
data = data + data
print(data)
# Out:
# [['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['len
# ...

# %%
data = data + data
print(data)
# Out:
# [['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['length', 82], ['fact', 'Abraham Lincoln loved cats. He had four of them while he lived in the White House.'], ['len
# ...

# %%
pretty = json.dumps(data, indent=4)

print(pretty)
# Out:
# [
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
#         "Abraham Lincoln loved cats. He had four of them while he lived in the White House."
#     ],
#     [
#         "length",
#         82
#     ],
#     [
#         "fact",
# ...

# %% [markdown]
# # Save the file

# %%
with open("out.json", "w+") as f:
    f.write(json.dumps(data))
